# %%
opcao = 1

while opcao == 1:
    print("Calculadora:")
    print("0 - Soma ")
    print("1 - Subtracao ")
    print("2 - Multiplicação ")
    print("3 - Divisão ")
    print("4 - Exponenciação ")
    
    print("Escolha a operação que deseja realizar:")
    op = int(input())
    
    if op == 0:
        print("Digite o primeiro valor")
        num1 = float(input())
        print("Digite o segundo valor")
        num2 = float(input())
        
        resul = num1 + num2
        
        print("O resultado é {}".format(resul))
    
    if op == 1:
        print("Digite o primeiro valor")
        num1 = float(input())
        print("Digite o segundo valor")
        num2 = float(input())
        
        resul = num1 - num2
        
        print("O resultado é {}".format(resul))
        
    if op == 2:
        print("Digite o primeiro valor")
        num1 = float(input())
        print("Digite o segundo valor")
        num2 = float(input())
        
        resul = num1 * num2
        
        print("O resultado é {}".format(resul))
        
    if op == 3:
        print("Digite o primeiro valor")
        num1 = float(input())
        print("Digite o segundo valor")
        num2 = float(input())
        
        resul = num1 / num2
        
        print("O resultado é {}".format(resul))
        
    if op == 4:
        print("Digite o primeiro valor")
        num1 = float(input())
        print("Digite o segundo valor")
        num2 = float(input())
        
        resul = num1**num2
        
        print("O resultado é {}".format(resul))
        
    print("Deseja fazer outra operação? NÃO - 0 SIM - 1")
    opcao = int(input())
# Out:
# Calculadora:
# 0 - Soma
# 1 - Subtracao
# 2 - Multiplicação
# 3 - Divisão
# 4 - Exponenciação
# Escolha a operação que deseja realizar:
# 0
# Digite o primeiro valor
# 2
# Digite o segundo valor
# 2
# O resultado é 4.0
# Deseja fazer outra operação? NÃO - 0 SIM - 1
# 1
# Calculadora:
# 0 - Soma
# 1 - Subtracao
# 2 - Multiplicação
# 3 - Divisão
# 4 - Exponenciação
# Escolha a operação que deseja realizar:
# 10
# Deseja fazer outra operação? NÃO - 0 SIM - 1
# 0
